# %%
# !pip install apache-airflow[postgres,s3]
# Out:
# Collecting apache-airflow[postgres,s3]
#   Downloading apache_airflow-2.1.4-py3-none-any.whl (5.3 MB)
# Collecting croniter<1.1,>=0.3.17
#   Downloading croniter-1.0.15-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: markdown<4.0,>=2.5.2 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (3.3.4)
# Collecting psutil<6.0.0,>=4.2.0
#   Downloading psutil-5.8.0-cp38-cp38-win_amd64.whl (245 kB)
# Collecting sqlalchemy-jsonfield~=1.0
#   Downloading SQLAlchemy_JSONField-1.0.0-py3-none-any.whl (10 kB)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: markupsafe<2.0,>=1.1.1 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (1.1.1)
# Collecting python-daemon>=2.2.4
#   Downloading python_daemon-2.3.0-py2.py3-none-any.whl (35 kB)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-2.0.1-py3-none-any.whl (15 kB)
# Collecting python-nvd3~=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-2.0.1-py3-none-any.whl (16 kB)
# Collecting cattrs<1.7.0,~=1.1
#   Downloading cattrs-1.5.0-py3-none-any.whl (19 kB)
# Collecting flask-wtf<0.15,>=0.14.3
#   Downloading Flask_WTF-0.14.3-py2.py3-none-any.whl (13 kB)
# Collecting httpx
#   Downloading httpx-0.19.0-py3-none-any.whl (77 kB)
# Collecting sqlalchemy>=1.3.18
#   Downloading SQLAlchemy-1.4.25-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting flask-caching<2.0.0,>=1.5.0
#   Downloading Flask_Caching-1.10.1-py3-none-any.whl (34 kB)
# Collecting flask-appbuilder<4.0.0,>=3.3.2
#   Downloading Flask_AppBuilder-3.3.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: numpy in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (1.19.5)
# Collecting argcomplete~=1.10
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting swagger-ui-bundle>=0.0.2
#   Downloading swagger_ui_bundle-0.0.9-py3-none-any.whl (6.2 MB)
# Collecting importlib-resources~=1.4
#   Downloading importlib_resources-1.5.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: jsonschema~=3.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (3.2.0)
# Collecting python3-openid~=3.2
#   Downloading python3_openid-3.2.0-py3-none-any.whl (133 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-2.0.1-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
# Collecting itsdangerous<2.0,>=1.1.0
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting docutils<0.17
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
# Collecting pyjwt<2
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-metadata>=1.7 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (3.10.0)
# Collecting openapi-spec-validator>=0.2.4
#   Downloading openapi_spec_validator-0.3.1-py3-none-any.whl (32 kB)
# Requirement already satisfied: jinja2<4,>=2.10.1 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (2.11.3)
# Collecting flask-login<0.5,>=0.3
#   Downloading Flask-Login-0.4.1.tar.gz (14 kB)
# Requirement already satisfied: python-dateutil<3,>=2.3 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (2.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (1.1.0)
# Collecting iso8601>=0.1.12
#   Downloading iso8601-0.1.16-py2.py3-none-any.whl (10 kB)
# Collecting tabulate<0.9,>=0.7.5
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: pygments<3.0,>=2.0.1 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (2.8.1)
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting alembic<2.0,>=1.2
#   Downloading alembic-1.7.3-py3-none-any.whl (208 kB)
# Collecting clickclick>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.6.0-cp38-cp38-win_amd64.whl (22 kB)
# Collecting werkzeug>=1.0.1,~=1.0
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting tenacity~=6.2.0
#   Downloading tenacity-6.2.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pandas<2.0,>=0.17.1 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (1.2.4)
# Collecting flask<2.0,>=1.1.0
#   Downloading Flask-1.1.4-py2.py3-none-any.whl (94 kB)
# Collecting python-slugify<5.0,>=3.0.0
#   Downloading python-slugify-4.0.1.tar.gz (11 kB)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-2.0.1-py3-none-any.whl (21 kB)
# Collecting setproctitle<2,>=1.1.8
#   Downloading setproctitle-1.2.2-cp38-cp38-win_amd64.whl (10 kB)
# Requirement already satisfied: attrs<21.0,>=20.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow[postgres,s3]) (20.3.0)
# Collecting dill<0.4,>=0.2.2
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting cryptography>=0.9.3
#   Downloading cryptography-3.4.8-cp36-abi3-win_amd64.whl (1.6 MB)
# Collecting colorlog<6.0,>=4.0.2
#   Downloading colorlog-5.0.1-py2.py3-none-any.whl (10 kB)
# Collecting rich>=9.2.0
#   Downloading rich-10.10.0-py3-none-any.whl (211 kB)
# Collecting graphviz>=0.12
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Collecting gunicorn>=19.5.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting inflection>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting pendulum~=2.0
#   Downloading pendulum-2.1.2-cp38-cp38-win_amd64.whl (129 kB)
# Collecting apache-airflow-providers-postgres
#   Downloading apache_airflow_providers_postgres-2.2.0-py3-none-any.whl (18 kB)
# Collecting apache-airflow-providers-amazon
#   Downloading apache_airflow_providers_amazon-2.2.0-py3-none-any.whl (287 kB)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
# Collecting click>=4.0
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: colorama in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from click>=4.0->clickclick>=1.2->apache-airflow[postgres,s3]) (0.4.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from cryptography>=0.9.3->apache-airflow[postgres,s3]) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow[postgres,s3]) (2.20)
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.37.8-py3-none-any.whl (100 kB)
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.1.3-py2.py3-none-any.whl (18 kB)
# Collecting Flask-Babel<2,>=1
#   Downloading Flask_Babel-1.0.0-py3-none-any.whl (9.5 kB)
# Collecting sqlalchemy>=1.3.18
#   Downloading SQLAlchemy-1.3.24-cp38-cp38-win_amd64.whl (1.2 MB)
# Collecting marshmallow-sqlalchemy<0.24.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.23.1-py2.py3-none-any.whl (18 kB)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.13.0-py2.py3-none-any.whl (47 kB)
# Collecting Flask-OpenID<2,>=1.2.5
#   Downloading Flask_OpenID-1.3.0-py3-none-any.whl (9.3 kB)
# Collecting Flask-JWT-Extended<4,>=3.18
#   Downloading Flask-JWT-Extended-3.25.1.tar.gz (32 kB)
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.1.0-py3-none-any.whl (241 kB)
# Requirement already satisfied: idna>=2.0.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder<4.0.0,>=3.3.2->apache-airflow[postgres,s3]) (3.2)
# Collecting Babel>=2.3
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
# Requirement already satisfied: pytz in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from Flask-Babel<2,>=1->flask-appbuilder<4.0.0,>=3.3.2->apache-airflow[postgres,s3]) (2021.1)
# Requirement already satisfied: six in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from Flask-JWT-Extended<4,>=3.18->flask-appbuilder<4.0.0,>=3.3.2->apache-airflow[postgres,s3]) (1.15.0)
# Collecting WTForms
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
# Requirement already satisfied: setuptools>=3.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from gunicorn>=19.5.0->apache-airflow[postgres,s3]) (52.0.0.post20210125)
# Requirement already satisfied: zipp>=0.5 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from importlib-metadata>=1.7->apache-airflow[postgres,s3]) (3.4.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from jsonschema~=3.0->apache-airflow[postgres,s3]) (0.17.3)
# Collecting openapi-schema-validator
#   Downloading openapi_schema_validator-0.1.5-py3-none-any.whl (7.9 kB)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: defusedxml in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from python3-openid~=3.2->apache-airflow[postgres,s3]) (0.7.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Collecting jsonpath-ng>=1.5.3
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting watchtower~=1.0.6
#   Downloading watchtower-1.0.6-py3-none-any.whl (13 kB)
# Collecting boto3<1.18.0,>=1.15.0
#   Downloading boto3-1.17.112-py2.py3-none-any.whl (131 kB)
# Collecting botocore<1.21.0,>=1.20.112
#   Downloading botocore-1.20.112-py2.py3-none-any.whl (7.7 MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from botocore<1.21.0,>=1.20.112->boto3<1.18.0,>=1.15.0->apache-airflow-providers-amazon->apache-airflow[postgres,s3]) (1.26.6)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: decorator in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from jsonpath-ng>=1.5.3->apache-airflow-providers-amazon->apache-airflow[postgres,s3]) (5.0.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from apache-airflow-providers-http->apache-airflow[postgres,s3]) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from requests>=2.26.0->apache-airflow-providers-http->apache-airflow[postgres,s3]) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\chua_\anaconda3\envs\bt4014\lib\site-packages (from requests>=2.26.0->apache-airflow-providers-http->apache-airflow[postgres,s3]) (2.0.6)
# Collecting psycopg2-binary>=2.7.4
#   Downloading psycopg2_binary-2.9.1-cp38-cp38-win_amd64.whl (1.1 MB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.14.0,>=0.13.3
#   Downloading httpcore-0.13.7-py3-none-any.whl (58 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting anyio==3.*
#   Downloading anyio-3.3.1-py3-none-any.whl (77 kB)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Building wheels for collected packages: Flask-JWT-Extended, flask-login, python-nvd3, python-slugify, unicodecsv, blinker
#   Building wheel for Flask-JWT-Extended (setup.py): started
#   Building wheel for Flask-JWT-Extended (setup.py): finished with status 'done'
#   Created wheel for Flask-JWT-Extended: filename=Flask_JWT_Extended-3.25.1-py2.py3-none-any.whl size=21599 sha256=560e5cfef8f36e30e19ede9a5eab220d590ee0181a30bd462b8ba2d62b9c280f
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\00\60\4a\7fc484ed75cc2baea756f0a3d07aa2065d09688d940c6fac1e
#   Building wheel for flask-login (setup.py): started
#   Building wheel for flask-login (setup.py): finished with status 'done'
#   Created wheel for flask-login: filename=Flask_Login-0.4.1-py2.py3-none-any.whl size=15936 sha256=f563780d71fb69f7011386afbfac6d78e140b43e62f00ebf4da04e9bfae9c1f0
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\ec\8e\42\16110a8b4f17e4ef4bd0abd42969fc1fc38229348de9f071df
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38156 sha256=fa34ec4eea8bcb5b4a4249a56a638f4e1870d659fe8b3178853c07a92b0e2f41
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\8c\92\61\c1d567a155a1f15d2e1a633eef32ed3a7c7906c323d49fa3a2
#   Building wheel for python-slugify (setup.py): started
#   Building wheel for python-slugify (setup.py): finished with status 'done'
#   Created wheel for python-slugify: filename=python_slugify-4.0.1-py2.py3-none-any.whl size=6769 sha256=179b32e470ec38964bbcc3db3d99aef5eec519cd3669bbc23ab32e3f1184473e
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\91\4d\4f\e740a68c215791688c46c4d6251770a570e8dfea91af1acb5c
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10767 sha256=f9ec6d6559374ac06222cd4e2a547079bf36feac87b3f7d055804958663b3ae4
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\35\dd\44\ccb37563a01457f5de74ccedccaee81b01a53e12addeab5e0f
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=d06685d0a63e3b144b8531b90923ab6aeec286a0c45fd8c6a5867ee56cb5b534
#   Stored in directory: c:\users\chua_\appdata\local\pip\cache\wheels\b7\a5\68\fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built Flask-JWT-Extended flask-login python-nvd3 python-slugify unicodecsv blinker
# Installing collected packages: werkzeug, sniffio, jmespath, itsdangerous, click, WTForms, text-unidecode, sqlalchemy, rfc3986, pyyaml, python3-openid, pyjwt, marshmallow, isodate, h11, flask, dnspython, botocore, Babel, apispec, anyio, sqlalchemy-utils, s3transfer, pytzdata, python-slugify, prison, openapi-schema-validator, marshmallow-sqlalchemy, marshmallow-enum, Mako, lockfile, importlib-resources, httpcore, flask-wtf, Flask-SQLAlchemy, Flask-OpenID, flask-login, Flask-JWT-Extended, Flask-Babel, email-validator, docutils, commonmark, unicodecsv, tenacity, tabulate, swagger-ui-bundle, sqlalchemy-jsonfield, setproctitle, rich, python-nvd3, python-daemon, psutil, ply, pendulum, openapi-spec-validator, marshmallow-oneofschema, lazy-object-proxy, iso8601, inflection, httpx, gunicorn, graphviz, flask-caching, flask-appbuilder, dill, cryptography, croniter, colorlog, clickclick, cattrs, boto3, blinker, argcomplete, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, alembic, watchtower, psycopg2-binary, jsonpath-ng, apache-airflow, apache-airflow-providers-postgres, apache-airflow-providers-amazon
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 2.0.1
#     Uninstalling Werkzeug-2.0.1:
#       Successfully uninstalled Werkzeug-2.0.1
# Successfully installed Babel-2.9.1 Flask-Babel-1.0.0 Flask-JWT-Extended-3.25.1 Flask-OpenID-1.3.0 Flask-SQLAlchemy-2.5.1 Mako-1.1.5 WTForms-2.3.3 alembic-1.7.3 anyio-3.3.1 apache-airflow-2.1.4 apache-airflow-providers-amazon-2.2.0 apache-airflow-providers-ftp-2.0.1 apache-airflow-providers-http-2.0.1 apache-airflow-providers-imap-2.0.1 apache-airflow-providers-postgres-2.2.0 apache-airflow-providers-sqlite-2.0.1 apispec-3.3.2 argcomplete-1.12.3 blinker-1.4 boto3-1.17.112 botocore-1.20.112 cattrs-1.5.0 click-7.1.2 clickclick-20.10.2 colorlog-5.0.1 commonmark-0.9.1 croniter-1.0.15 cryptography-3.4.8 dill-0.3.4 dnspython-2.1.0 docutils-0.16 email-validator-1.1.3 flask-1.1.4 flask-appbuilder-3.3.3 flask-caching-1.10.1 flask-login-0.4.1 flask-wtf-0.14.3 graphviz-0.17 gunicorn-20.1.0 h11-0.12.0 httpcore-0.13.7 httpx-0.19.0 importlib-resources-1.5.0 inflection-0.5.1 iso8601-0.1.16 isodate-0.6.0 itsdangerous-1.1.0 jmespath-0.10.0 jsonpath-ng-1.5.3 lazy-object-proxy-1.6.0 lockfile-0.12.2 marshmallow-3.13.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.23.1 openapi-schema-validator-0.1.5 openapi-spec-validator-0.3.1 pendulum-2.1.2 ply-3.11 prison-0.2.1 psutil-5.8.0 psycopg2-binary-2.9.1 pyjwt-1.7.1 python-daemon-2.3.0 python-nvd3-0.15.0 python-slugify-4.0.1 python3-openid-3.2.0 pytzdata-2020.1 pyyaml-5.4.1 rfc3986-1.5.0 rich-10.10.0 s3transfer-0.4.2 setproctitle-1.2.2 sniffio-1.2.0 sqlalchemy-1.3.24 sqlalchemy-jsonfield-1.0.0 sqlalchemy-utils-0.37.8 swagger-ui-bundle-0.0.9 tabulate-0.8.9 tenacity-6.2.0 text-unidecode-1.3 unicodecsv-0.14.1 watchtower-1.0.6 werkzeug-1.0.1

# %%
from airflow import DAG
from airflow.operators.bash import BashOperator
from datetime import datetime, timedelta

schedule_interval='0 * 1-14 * *'

default_args = {
    'owner': 'airflow',
    'depends_on_past': False,
    'start_date': datetime(2015, 12, 1),
    'email': ['airflow@example.com'],
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 1,
    'retry_delay': timedelta(minutes=5),
    'schedule_interval': '@hourly',
}

dag = DAG('tutorial', catchup=False, default_args=default_args)
